# %% [markdown]
# INSTALLING LIBRARIES/DEPENDENCIES NEEDED

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import csv

# %% [markdown]
# Uploading the dataset (.csv files)

# %%
employeeNumber = 'datasets/employment.csv'

# %% [markdown]
# Reading the datasets(.csv files)

# %%
employeeNumber = pd.read_csv(employeeNumber)

# %% [markdown]
# Renaming Column Names

# %%
employeeNumber.rename(columns={'year': 'Year','philippines': 'Philippines','capital': 'NCR','administrative': 'CAR','region': 'Region I','region_2': 'Region II','region_3': 'Region III',
                               'region_4': 'Region IV-A','region_5': 'Region IV-B'}, inplace=True)
employeeNumber
# Out:
#      Year  Philippines Capital     Car Region 1 Region 2 Region IV-A
# 0     NaN          NaN  Region  Region        I       II         III  \
# 1  2012.0      53144.0    7566     974     2870     2129        5548
# 2  2013.0      54388.0    7679    1003     2972     2010        5716
# 3  2014.0      55230.0    7363     990     3088     2012        6091
# 4  2015.0      56565.0    7509    1024     3142     2056        6227
# 5  2016.0      57848.0    7638    1051     3214     2108        6368
# 6  2017.0      59237.0    7764  1067.5   3315.5     2150     6530.75
# 7  2018.0      60717.0    7922    1105     3394     2192        6682
# 8  2019.0      61882.0    7979    1121     3467     2225        6828
#
#   Region IV-A Region IV-B region_6 region_7 region_8 region_9 region_10
# 0        IV-A        IV-B        V       VI      VII     VIII        IX  \
# 1        6445        1459     3026     4380     3853     2453      1948
# ...
