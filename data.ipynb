# %% [markdown]
# INSTALLING LIBRARIES/DEPENDENCIES NEEDED

# %%
import numpy as np
import pandas as pd
import matplotlib. pyplot as plt
import csv
import seaborn as sns

# %% [markdown]
# Uploading the dataset (.csv files)

# %%
employeeNumber = 'datasets/employment.csv'

# %% [markdown]
# Reading the datasets(.csv files)

# %%
employeeNumber = pd.read_csv(employeeNumber)

# %% [markdown]
# Renaming Column Names

# %%
employeeNumber.rename(columns={'year':'Year','capital':'NCR','administrative':'CAR','region':'Region I','region_2': 'Region II', 'region_3':'Region III', 'region_4':'Region IV-A', 'region_5':'Region IV-B', 'region_6':'Region V'
                                       , 'region_7':'Region VI','region_8': 'Region VII','region_9': 'Region VIII', 'region_10':'Region IX','region_11': 'Region X', 'region_12':'Region XI', 'region_13':'Region XII'
                                       ,'region_14': 'Region XIII', 'armm':'ARMM'}, inplace=True)
employeeNumber
# Out:
#    Year  philippines   NCR     CAR  Region I  Region II  Region III
# 0  2012        53144  7566   974.0    2870.0       2129     5548.00  \
# 1  2013        54388  7679  1003.0    2972.0       2010     5716.00
# 2  2014        55230  7363   990.0    3088.0       2012     6091.00
# 3  2015        56565  7509  1024.0    3142.0       2056     6227.00
# 4  2016        57848  7638  1051.0    3214.0       2108     6368.00
# 5  2017        59237  7764  1067.5    3315.5       2150     6530.75
# 6  2018        60717  7922  1105.0    3394.0       2192     6682.00
# 7  2019        61882  7979  1121.0    3467.0       2225     6828.00
#
#    Region IV-A  Region IV-B  Region V  Region VI  Region VII  Region VIII
# 0       6445.0      1459.00   3026.00       4380        3853       2453.0  \
# 1       6665.0      1497.00   3113.00       4479        3971       2528.0
# 2       7052.0      1619.00   3104.00       4488        4215       2452.0
# ...

# %% [markdown]
# Removing first column of the table

# %%
employeeNumber.drop('philippines', axis=1, inplace=True)

employeeNumber
# Out:
#    Year   NCR     CAR  Region I  Region II  Region III  Region IV-A
# 0  2012  7566   974.0    2870.0       2129     5548.00       6445.0  \
# 1  2013  7679  1003.0    2972.0       2010     5716.00       6665.0
# 2  2014  7363   990.0    3088.0       2012     6091.00       7052.0
# 3  2015  7509  1024.0    3142.0       2056     6227.00       7233.0
# 4  2016  7638  1051.0    3214.0       2108     6368.00       7415.0
# 5  2017  7764  1067.5    3315.5       2150     6530.75       7595.5
# 6  2018  7922  1105.0    3394.0       2192     6682.00       7808.0
# 7  2019  7979  1121.0    3467.0       2225     6828.00       7988.0
#
#    Region IV-B  Region V  Region VI  Region VII  Region VIII  Region IX
# 0      1459.00   3026.00       4380        3853       2453.0     1948.0  \
# 1      1497.00   3113.00       4479        3971       2528.0     2027.0
# 2      1619.00   3104.00       4488        4215       2452.0     1972.0
# ...

# %% [markdown]
# Checking for nul values

# %%
employeeNumber.isnull().sum()
# Out:
# Year           0
# NCR            0
# CAR            0
# Region I       0
# Region II      0
# Region III     0
# Region IV-A    0
# Region IV-B    0
# Region V       0
# Region VI      0
# Region VII     0
# Region VIII    0
# Region IX      0
# Region X       0
# Region XI      0
# Region XII     0
# Region XIII    0
# ARMM           0
# dtype: int64

# %%
employeeNumber.head()
# Out:
#    Year   NCR     CAR  Region I  Region II  Region III  Region IV-A
# 0  2012  7566   974.0    2870.0       2129      5548.0       6445.0  \
# 1  2013  7679  1003.0    2972.0       2010      5716.0       6665.0
# 2  2014  7363   990.0    3088.0       2012      6091.0       7052.0
# 3  2015  7509  1024.0    3142.0       2056      6227.0       7233.0
# 4  2016  7638  1051.0    3214.0       2108      6368.0       7415.0
#
#    Region IV-B  Region V  Region VI  Region VII  Region VIII  Region IX
# 0       1459.0    3026.0       4380        3853       2453.0     1948.0  \
# 1       1497.0    3113.0       4479        3971       2528.0     2027.0
# 2       1619.0    3104.0       4488        4215       2452.0     1972.0
# 3       1655.0    3172.0       4593        4313       2536.0     2022.0
# 4       1709.0    3244.0       4707        4381       2603.0     2072.0
#
#    Region X  Region XI  Region XII  Region XIII    ARMM
# 0      2481     2570.0      2286.0         1478  1680.0
# ...

# %%
description=employeeNumber.describe().T
print(description)
# Out:
#              count        mean         std     min      25%     50%
# Year           8.0  2015.50000    2.449490  2012.0  2013.75  2015.5  \
# NCR            8.0  7677.50000  206.833957  7363.0  7551.75  7658.5
# CAR            8.0  1041.93750   53.604662   974.0   999.75  1037.5
# Region I       8.0  3182.81250  205.943810  2870.0  3059.00  3178.0
# Region II      8.0  2110.25000   79.672096  2010.0  2045.00  2118.5
# Region III     8.0  6248.84375  449.954262  5548.0  5997.25  6297.5
# Region IV-A    8.0  7275.18750  538.154382  6445.0  6955.25  7324.0
# Region IV-B    8.0  1676.09375  148.413752  1459.0  1588.50  1682.0
# Region V       8.0  3235.46875  159.184890  3026.0  3110.75  3208.0
# Region VI      8.0  4684.50000  243.987119  4380.0  4485.75  4650.0
# Region VII     8.0  4317.12500  294.593394  3853.0  4154.00  4347.0
# Region VIII    8.0  2593.81250  124.135277  2452.0  2509.25  2569.5
# Region IX      8.0  2072.31250  102.508863  1948.0  2009.50  2049.5
# ...

# %%
plt.figure(figsize=(12, 8))

plt.bar(employeeNumber['Year'], employeeNumber['NCR'], color=['#fbf8cc', '#ffcfd2', '#cfbaf0', '#a3c4f3', '#90dbf4', '#8eecf5', '#98f5e1', '#b9fbc0'])

plt.title("Employment Status of the Philippines in year 2012 to 2019")
plt.xlabel('Year', fontsize=14)
plt.ylabel('National Capital Region', fontsize=14)
plt.grid(True)

plt.show()

# %%
# Use describe() to get descriptive statistics for all columns
description = employeeNumber.describe()
plt.figure(figsize=(12, 8))
# Plotting the mean values
description.loc['mean'].plot(kind='bar')

# Adding labels and title
plt.xlabel('Columns')
plt.ylabel('Mean')
plt.title('Mean Values of Columns')

# Display the plot
plt.show()

# %%
description = employeeNumber.describe()
# Extract the statistics you want to visualize
statistics = description.loc[['count', 'mean', 'std', 'min', '25%', '50%']]
# Transpose the DataFrame for easier plotting
statistics = statistics.T
# Adjust figure size
plt.figure(figsize=(12, 8))
# Plotting the line graph
statistics.plot(kind='line', marker='o')
# Adding labels and title
plt.xlabel('Columns')
plt.ylabel('Value')
plt.title('Descriptive Statistics')
# Adjust font size
plt.xticks(range(len(statistics.index)), statistics.index, fontsize=8)
plt.xticks(rotation=90)
# Display the plot
plt.legend(loc='upper right')
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
employeeNumber.rename(columns={'Region I': 'RegionI','Region II': 'RegionII','Region III': 'RegionIII','Region IV-A': 'RegionIVA'
                               ,'Region IV-B': 'RegionIVB','Region V': 'RegionV','Region VI': 'RegionVI','Region VII': 'RegionVII',
                               'Region VIII': 'RegionVIII', 'Region IX': 'RegionIX','Region X': 'RegionX','Region XI': 'RegionXI'
                               ,'Region XII': 'RegionXII','Region XIII': 'RegionXIII'}, inplace=True)
employeeNumber
# Out:
#    Year   NCR     CAR  RegionI  RegionII  RegionIII  RegionIVA  RegionIVB
# 0  2012  7566   974.0   2870.0      2129    5548.00     6445.0    1459.00  \
# 1  2013  7679  1003.0   2972.0      2010    5716.00     6665.0    1497.00
# 2  2014  7363   990.0   3088.0      2012    6091.00     7052.0    1619.00
# 3  2015  7509  1024.0   3142.0      2056    6227.00     7233.0    1655.00
# 4  2016  7638  1051.0   3214.0      2108    6368.00     7415.0    1709.00
# 5  2017  7764  1067.5   3315.5      2150    6530.75     7595.5    1772.75
# 6  2018  7922  1105.0   3394.0      2192    6682.00     7808.0    1822.00
# 7  2019  7979  1121.0   3467.0      2225    6828.00     7988.0    1875.00
#
#    RegionV  RegionVI  RegionVII  RegionVIII  RegionIX  RegionX  RegionXI
# 0  3026.00      4380       3853      2453.0    1948.0     2481   2570.00  \
# 1  3113.00      4479       3971      2528.0    2027.0     2550   2523.00
# 2  3104.00      4488       4215      2452.0    1972.0     2520   2611.00
# ...

# %%
import matplotlib.ticker as ticker

fig, ax = plt.subplots(figsize=(20, 10), dpi=80)
ax.bar(employeeNumber.loc[0:7, 'Year'], employeeNumber.loc[0:7, 'NCR'], label='NCR')
ax.bar(employeeNumber.loc[0:7, 'Year'], employeeNumber.loc[0:7, 'CAR'], label='CAR')
ax.bar(employeeNumber.loc[0:7, 'Year'], employeeNumber.loc[0:7, 'RegionI'], label='Region I')
ax.bar(employeeNumber.loc[0:7, 'Year'], employeeNumber.loc[0:7, 'RegionII'], label='Region II')
ax.bar(employeeNumber.loc[0:7, 'Year'], employeeNumber.loc[0:7, 'RegionIII'], label='Region III')
ax.bar(employeeNumber.loc[0:7, 'Year'], employeeNumber.loc[0:7, 'RegionIVA'], label='Region IV-A')
ax.bar(employeeNumber.loc[0:7, 'Year'], employeeNumber.loc[0:7, 'RegionIVB'], label='Region IV-B')
ax.bar(employeeNumber.loc[0:7, 'Year'], employeeNumber.loc[0:7, 'RegionV'], label='Region V')
ax.bar(employeeNumber.loc[0:7, 'Year'], employeeNumber.loc[0:7, 'RegionVI'], label='Region VI')
ax.bar(employeeNumber.loc[0:7, 'Year'], employeeNumber.loc[0:7, 'RegionVII'], label='Region VII')
ax.bar(employeeNumber.loc[0:7, 'Year'], employeeNumber.loc[0:7, 'RegionVIII'], label='Region VIII')
ax.bar(employeeNumber.loc[0:7, 'Year'], employeeNumber.loc[0:7, 'RegionIX'], label='Region IX')
ax.bar(employeeNumber.loc[0:7, 'Year'], employeeNumber.loc[0:7, 'RegionX'], label='Region X')
ax.bar(employeeNumber.loc[0:7, 'Year'], employeeNumber.loc[0:7, 'RegionXI'], label='Region XI')
ax.bar(employeeNumber.loc[0:7, 'Year'], employeeNumber.loc[0:7, 'RegionXII'], label='Region XII')
ax.bar(employeeNumber.loc[0:7, 'Year'], employeeNumber.loc[0:7, 'RegionXI'], label='Region XIII')
ax.bar(employeeNumber.loc[0:7, 'Year'], employeeNumber.loc[0:7, 'ARMM'], label='ARMM')

ax.legend()
tick_spacing = 1
ax.ticklabel_format(useOffset=False, style='plain')
ax.xaxis.set_major_locator(ticker.MultipleLocator(tick_spacing))

plt.xticks(rotation=90)
plt.ylabel('People', fontsize=15)
plt.xlabel('Year', fontsize=15)

subtitle = [
    "Number of People Employed", 
]

fig.text(
    0.30,
    0.97,
    "Employment Status of Phillipines in year of 2012 to 2019",
    color='black',
    fontsize=15,
    fontname="sans-serif",
    weight="bold"
)

fig.text(
    0.40,
    0.91,
    "\n".join(subtitle),
    ha="left",
    color='black',
    fontname="sans-serif",
    fontsize=13,
)
plt.show()

# %%
fig, axs = plt.subplots(4, 5, figsize=(18, 16))

for i, column in enumerate(employeeNumber.columns[:18]):  # Limiting to the first 18 columns
    sns.histplot(employeeNumber[column], color='C{}'.format(i), bins=100, kde=True, ax=axs[i//5, i%5])
    axs[i//5, i%5].set_xlabel(column)

plt.tight_layout()
plt.show()

# %%
# convert data to numpy array
var_to_analyze = np.asarray(employeeNumber['CAR'])

# calculate mean and standard deviation
mean, sd = np.mean(var_to_analyze), np.std(var_to_analyze)

# determine threshold and detect outliers
threshold = 2.5
outliers = var_to_analyze[np.abs((var_to_analyze - mean) / sd) > threshold]

# print outliers    
print("The detected outliers are: ", outliers)

# remove outliers from the original dataset
var_clean = var_to_analyze[np.abs((var_to_analyze - mean) / sd) <= threshold]

var_clean = pd.DataFrame(var_clean, columns=['CAR'])


# print the cleaned dataset
print("The cleaned var without outliers is: ", var_clean)
# Out:
# The detected outliers are:  []
# The cleaned var without outliers is:        CAR
# 0   974.0
# 1  1003.0
# 2   990.0
# 3  1024.0
# 4  1051.0
# 5  1067.5
# 6  1105.0
# 7  1121.0

# %%
sns.histplot(employeeNumber['CAR'])
# Out:
# <Axes: xlabel='CAR', ylabel='Count'>

# %%
sns.histplot(var_clean['CAR'])
# Out:
# <Axes: xlabel='CAR', ylabel='Count'>

# %%
sns.scatterplot(employeeNumber['CAR'])
# Out:
# <Axes: ylabel='CAR'>

# %%
print(np.var(employeeNumber['CAR']))
# Out:
# 2514.27734375
